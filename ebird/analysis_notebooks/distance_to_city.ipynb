# %%
import pandas as pd

# Download SimpleMaps free CSV
url = "https://simplemaps.com/static/data/world-cities/basic/simplemaps_worldcities_basicv1.77.zip"

# Or use geopandas with Natural Earth data
import geopandas as gpd
world = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
europe = world[world.geometry.x.between(-25, 45) & world.geometry.y.between(34, 72)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       6 # Or use geopandas with Natural Earth data
#       7 import geopandas as gpd
# ----> 8 world = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
#       9 europe = world[world.geometry.x.between(-25, 45) & world.geometry.y.between(34, 72)]
#
# File c:\Users\Radu\miniconda3\envs\ml\lib\site-packages\geopandas\datasets\__init__.py:18, in get_path(dataset)
#      12 error_msg = (
#      13     "The geopandas.dataset has been deprecated and was removed in GeoPandas "
#      14     f"1.0. You can get the original '{dataset}' data from "
#      15     f"{ne_message if 'natural' in dataset else nybb_message}"
#      16 )
#      17 if dataset in _prev_available:
# ---> 18     raise AttributeError(error_msg)
#      19 else:
#      20     error_msg = (
#      21         "The geopandas.dataset has been deprecated and "
#      22         "was removed in GeoPandas 1.0. New sample datasets are now available "
#      23         "in the geodatasets package (https://geodatasets.readthedocs.io/en/latest/)"
#      24     )
#
# AttributeError: The geopandas.dataset has been deprecated and was removed in GeoPandas 1.0. You can get the original 'naturalearth_cities' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.

# %%
import geopandas as gpd

# Download directly from Natural Earth
url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_populated_places.zip"
world = gpd.read_file(url)

# Filter for Europe
europe = world[world.geometry.x.between(-25, 45) & world.geometry.y.between(34, 72)]

# Keep useful columns
europe_df = europe[['NAME', 'geometry']].copy()
europe_df['lon'] = europe_df.geometry.x
europe_df['lat'] = europe_df.geometry.y

print(europe_df[['NAME', 'lat', 'lon']].head())
# Out:
#             NAME        lat        lon
# 0   Vatican City  41.903282  12.453387
# 1     San Marino  43.936096  12.441770
# 2          Vaduz  47.133724   9.516670
# 4     Luxembourg  49.611660   6.130003
# 10        Monaco  43.739646   7.406913

# %%
europe_df.shape
# Out:
# (55, 4)

# %% [markdown]
# ### Increase resolution (:10milion)

# %%
import geopandas as gpd

# Use 10m scale instead of 110m — way more cities
url = "https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_populated_places.zip"
world = gpd.read_file(url)

# Filter for Europe
europe = world[world.geometry.x.between(-25, 45) & world.geometry.y.between(34, 72)]

# Keep useful columns
europe_df = europe[['NAME', 'ADM0NAME', 'POP_MAX', 'geometry']].copy()
europe_df['lon'] = europe_df.geometry.x
europe_df['lat'] = europe_df.geometry.y
europe_df = europe_df.drop(columns='geometry')

# Optional: sort by population
europe_df = europe_df.sort_values('POP_MAX', ascending=False)

print(f"Total cities: {len(europe_df)}")
print(europe_df.head(10))

# Save to CSV
europe_df.to_csv("europe_cities.csv", index=False)
# Out:
# Total cities: 1148
#                  NAME        ADM0NAME   POP_MAX        lon        lat
# 7266           Moscow          Russia  10452000  37.613577  55.754110
# 7263         Istanbul          Turkey  10061000  28.974277  41.017602
# 7278            Paris          France   9904000   2.352992  48.858092
# 7262           London  United Kingdom   8567000  -0.118668  51.501941
# 7229           Madrid           Spain   5567000  -3.685297  40.401972
# 7122        Barcelona           Spain   4920000   2.181424  41.385245
# 7135  St.  Petersburg          Russia   4553000  30.314074  59.940960
# 7119           Ankara          Turkey   3716000  32.862446  39.929184
# 7241           Berlin         Germany   3406000  13.399603  52.523764
# 7215          Algiers         Algeria   3354000   3.048607  36.765011

# %% [markdown]
# ## Birds

# %%
df_native = pd.read_csv("native_species_europe_only_cleaned.csv")
df_migratory = pd.read_csv("migra_species_europe_only_cleaned.csv")
# Out:
# C:\Users\Radu\AppData\Local\Temp\ipykernel_33900\3161389599.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_native = pd.read_csv("native_species_europe_only_cleaned.csv")

# %%
df_native
# Out:
#                       COMMON NAME     SCIENTIFIC NAME  OBSERVATION COUNT  \
# 0        Great Spotted Woodpecker   Dendrocopos major                1.0
# 1        Great Spotted Woodpecker   Dendrocopos major                1.0
# 2        Great Spotted Woodpecker   Dendrocopos major                3.0
# 3        Great Spotted Woodpecker   Dendrocopos major                5.0
# 4        Great Spotted Woodpecker   Dendrocopos major                2.0
# ...                           ...                 ...                ...
# 4024140            European Robin  Erithacus rubecula                1.0
# 4024141            European Robin  Erithacus rubecula                1.0
# 4024142            European Robin  Erithacus rubecula                1.0
# 4024143            European Robin  Erithacus rubecula                1.0
# 4024144            European Robin  Erithacus rubecula                1.0
#
#         AGE/SEX                  COUNTRY COUNTRY CODE  \
# 0           NaN                 Portugal           PT
# 1           NaN                  Ukraine           UA
# 2           NaN                    Spain           ES
# 3           NaN                  Croatia           HR
# 4           NaN           United Kingdom           GB
# ...         ...                      ...          ...
# 4024140     NaN  Vatican City (Holy See)           VA
# 4024141     NaN  Vatican City (Holy See)           VA
# 4024142     NaN  Vatican City (Holy See)           VA
# 4024143     NaN  Vatican City (Holy See)           VA
# 4024144     NaN  Vatican City (Holy See)           VA
#
#                                      STATE STATE CODE           COUNTY  \
# 0                               Portalegre      PT-12  Castelo de Vide
# 1                   Kirovohrads'ka Oblast'      UA-35              NaN
# 2                     Madrid, Comunidad de      ES-MD              NaN
# 3        Koprivnicko-kriÅ¾evacka Å¾upanija      HR-06              NaN
# 4                                 Scotland     GB-SCT             Fife
# ...                                    ...        ...              ...
# 4024140            Vatican City (Holy See)        VA-              NaN
# 4024141            Vatican City (Holy See)        VA-              NaN
# 4024142            Vatican City (Holy See)        VA-              NaN
# 4024143            Vatican City (Holy See)        VA-              NaN
# 4024144            Vatican City (Holy See)        VA-              NaN
#
#         COUNTY CODE  ...  OBSERVATION DATE  OBSERVER ID  \
# 0          PT-12-CV  ...        2018-01-26   obsr429991
# 1               NaN  ...        2018-12-22  obsr1017757
# 2               NaN  ...        2018-01-21   obsr771146
# 3               NaN  ...        2018-01-06   obsr733488
# 4        GB-SCT-FIF  ...        2018-06-09   obsr407628
# ...             ...  ...               ...          ...
# 4024140         NaN  ...        2022-04-09   obsr644609
# 4024141         NaN  ...        2022-05-05   obsr112798
# 4024142         NaN  ...        2022-10-07  obsr1771248
# 4024143         NaN  ...        2022-12-12   obsr988333
# 4024144         NaN  ...        2022-12-12  obsr1596592
#
#         SAMPLING EVENT IDENTIFIER OBSERVATION TYPE       obsDt  year month  \
# 0                       S42251764       Stationary  2018-01-26  2018     1
# 1                       S50893829        Traveling  2018-12-22  2018    12
# 2                       S42131687        Traveling  2018-01-21  2018     1
# 3                       S41672345        Traveling  2018-01-06  2018     1
# 4                       S46534187        Traveling  2018-06-09  2018     6
# ...                           ...              ...         ...   ...   ...
# 4024140                S106631527       Stationary  2022-04-09  2022     4
# 4024141                S108980796        Traveling  2022-05-05  2022     5
# 4024142                S120180143       Incidental  2022-10-07  2022    10
# 4024143                S123861665       Stationary  2022-12-12  2022    12
# 4024144                S123861666       Stationary  2022-12-12  2022    12
#
#         day_of_week day_of_year howMany
# 0                 4          26     1.0
# 1                 5         356     1.0
# 2                 6          21     3.0
# 3                 5           6     5.0
# 4                 5         160     2.0
# ...             ...         ...     ...
# 4024140           5          99     1.0
# 4024141           3         125     1.0
# 4024142           4         280     1.0
# 4024143           0         346     1.0
# 4024144           0         346     1.0
#
# [4024145 rows x 26 columns]

# %%
df_migratory
# Out:
#               COMMON NAME    SCIENTIFIC NAME  OBSERVATION COUNT AGE/SEX  \
# 0       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 1       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 2       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 3       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 4       Eurasian Whimbrel  Numenius phaeopus                3.0     NaN
# ...                   ...                ...                ...     ...
# 863367         Black Tern   Chlidonias niger                1.0     NaN
# 863368         Black Tern   Chlidonias niger                1.0     NaN
# 863369         Black Tern   Chlidonias niger                1.0     NaN
# 863370         Black Tern   Chlidonias niger                1.0     NaN
# 863371         Black Tern   Chlidonias niger                2.0     NaN
#
#                COUNTRY COUNTRY CODE               STATE STATE CODE  \
# 0                Spain           ES          AndalucÃ­a      ES-AN
# 1                Spain           ES          AndalucÃ­a      ES-AN
# 2                Spain           ES          AndalucÃ­a      ES-AN
# 3                Spain           ES          AndalucÃ­a      ES-AN
# 4                Spain           ES            Canarias      ES-CN
# ...                ...          ...                 ...        ...
# 863367     Netherlands           NL        Zuid-Holland      NL-ZH
# 863368          Poland           PL  Kujawsko-pomorskie      PL-KP
# 863369  United Kingdom           GB             England     GB-ENG
# 863370         Ireland           IE           Connaught       IE-C
# 863371         Ireland           IE            Leinster       IE-L
#
#                COUNTY COUNTY CODE  ...  OBSERVATION DATE  OBSERVER ID  \
# 0              CÃ¡diz    ES-AN-CD  ...        2017-01-20   obsr756857
# 1              Huelva    ES-AN-HL  ...        2017-01-16   obsr271019
# 2              Huelva    ES-AN-HL  ...        2017-01-16   obsr427437
# 3              Huelva    ES-AN-HL  ...        2017-01-16   obsr546444
# 4       Fuerteventura   ES-CN-FVT  ...        2017-01-21   obsr777138
# ...               ...         ...  ...               ...          ...
# 863367            NaN         NaN  ...        2025-09-16  obsr1478235
# 863368            NaN         NaN  ...        2025-09-19   obsr511948
# 863369     Merseyside  GB-ENG-KWL  ...        2025-10-05  obsr3384199
# 863370           Mayo     IE-C-MO  ...        2025-10-09   obsr685602
# 863371         Dublin     IE-L-DN  ...        2025-10-02   obsr937490
#
#        SAMPLING EVENT IDENTIFIER OBSERVATION TYPE       obsDt  year month  \
# 0                      S33804365        Traveling  2017-01-20  2017     1
# 1                      S33940654        Traveling  2017-01-16  2017     1
# 2                      S33751745        Traveling  2017-01-16  2017     1
# 3                      S34018122        Traveling  2017-01-16  2017     1
# 4                      S33908528        Traveling  2017-01-21  2017     1
# ...                          ...              ...         ...   ...   ...
# 863367                S273768812       Stationary  2025-09-16  2025     9
# 863368                S274163270       Stationary  2025-09-19  2025     9
# 863369                S277528628        Traveling  2025-10-05  2025    10
# 863370                S278224399        Traveling  2025-10-09  2025    10
# 863371                S276796960       Stationary  2025-10-02  2025    10
#
#        day_of_week day_of_year howMany
# 0                4          20     2.0
# 1                0          16     2.0
# 2                0          16     2.0
# 3                0          16     2.0
# 4                5          21     3.0
# ...            ...         ...     ...
# 863367           1         259     1.0
# 863368           4         262     1.0
# 863369           6         278     1.0
# 863370           3         282     1.0
# 863371           3         275     2.0
#
# [863372 rows x 26 columns]

# %% [markdown]
# ## Best option

# %%
# Load European cities
url = "https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_populated_places.zip"
import geopandas as gpd
world = gpd.read_file(url)
europe = world[world.geometry.x.between(-25, 45) & world.geometry.y.between(34, 72)]
cities = europe[['NAME', 'ADM0NAME', 'geometry']].copy()
cities['lon'] = cities.geometry.x
cities['lat'] = cities.geometry.y
cities = cities.drop(columns='geometry').reset_index(drop=True)
cities
# Out:
#              NAME        ADM0NAME        lon        lat
# 0        L'Ariana         Tunisia  10.199998  36.866673
# 1        Jendouba         Tunisia   8.749999  36.500004
# 2       Kasserine         Tunisia   8.716698  35.216703
# 3     Sdid Bouzid         Tunisia   9.500004  35.016696
# 4         Siliana         Tunisia   9.383302  36.083304
# ...           ...             ...        ...        ...
# 1143       London  United Kingdom  -0.118668  51.501941
# 1144     Istanbul          Turkey  28.974277  41.017602
# 1145       Moscow          Russia  37.613577  55.754110
# 1146         Rome           Italy  12.481313  41.897902
# 1147        Paris          France   2.352992  48.858092
#
# [1148 rows x 4 columns]

# %% [markdown]
# ## Native

# %%
import pandas as pd
import numpy as np
from scipy.spatial import cKDTree

# build KD-Tree on city coordinates ---
# convert lat/lon to radians for accurate distance calculation
cities_rad = np.radians(cities[['lat', 'lon']].values)
tree = cKDTree(cities_rad)

# find closest city for each bird observation ---
birds_rad = np.radians(df_native[['LATITUDE', 'LONGITUDE']].values)
distances, indices = tree.query(birds_rad, k=1)

# convert distance from radians to kilometers (Earth radius = 6371 km)
df_native['closest_city'] = cities['NAME'].iloc[indices].values
df_native['closest_city_country'] = cities['ADM0NAME'].iloc[indices].values
df_native['distance_km'] = np.round(distances * 6371, 2)

df_native
# Out:
#                       COMMON NAME     SCIENTIFIC NAME  OBSERVATION COUNT  \
# 0        Great Spotted Woodpecker   Dendrocopos major                1.0
# 1        Great Spotted Woodpecker   Dendrocopos major                1.0
# 2        Great Spotted Woodpecker   Dendrocopos major                3.0
# 3        Great Spotted Woodpecker   Dendrocopos major                5.0
# 4        Great Spotted Woodpecker   Dendrocopos major                2.0
# ...                           ...                 ...                ...
# 4024140            European Robin  Erithacus rubecula                1.0
# 4024141            European Robin  Erithacus rubecula                1.0
# 4024142            European Robin  Erithacus rubecula                1.0
# 4024143            European Robin  Erithacus rubecula                1.0
# 4024144            European Robin  Erithacus rubecula                1.0
#
#         AGE/SEX                  COUNTRY COUNTRY CODE  \
# 0           NaN                 Portugal           PT
# 1           NaN                  Ukraine           UA
# 2           NaN                    Spain           ES
# 3           NaN                  Croatia           HR
# 4           NaN           United Kingdom           GB
# ...         ...                      ...          ...
# 4024140     NaN  Vatican City (Holy See)           VA
# 4024141     NaN  Vatican City (Holy See)           VA
# 4024142     NaN  Vatican City (Holy See)           VA
# 4024143     NaN  Vatican City (Holy See)           VA
# 4024144     NaN  Vatican City (Holy See)           VA
#
#                                      STATE STATE CODE           COUNTY  \
# 0                               Portalegre      PT-12  Castelo de Vide
# 1                   Kirovohrads'ka Oblast'      UA-35              NaN
# 2                     Madrid, Comunidad de      ES-MD              NaN
# 3        Koprivnicko-kriÅ¾evacka Å¾upanija      HR-06              NaN
# 4                                 Scotland     GB-SCT             Fife
# ...                                    ...        ...              ...
# 4024140            Vatican City (Holy See)        VA-              NaN
# 4024141            Vatican City (Holy See)        VA-              NaN
# 4024142            Vatican City (Holy See)        VA-              NaN
# 4024143            Vatican City (Holy See)        VA-              NaN
# 4024144            Vatican City (Holy See)        VA-              NaN
#
#         COUNTY CODE  ...  OBSERVATION TYPE       obsDt  year month  \
# 0          PT-12-CV  ...        Stationary  2018-01-26  2018     1
# 1               NaN  ...         Traveling  2018-12-22  2018    12
# 2               NaN  ...         Traveling  2018-01-21  2018     1
# 3               NaN  ...         Traveling  2018-01-06  2018     1
# 4        GB-SCT-FIF  ...         Traveling  2018-06-09  2018     6
# ...             ...  ...               ...         ...   ...   ...
# 4024140         NaN  ...        Stationary  2022-04-09  2022     4
# 4024141         NaN  ...         Traveling  2022-05-05  2022     5
# 4024142         NaN  ...        Incidental  2022-10-07  2022    10
# 4024143         NaN  ...        Stationary  2022-12-12  2022    12
# 4024144         NaN  ...        Stationary  2022-12-12  2022    12
#
#          day_of_week  day_of_year howMany  closest_city closest_city_country  \
# 0                  4           26     1.0    Portalegre             Portugal
# 1                  5          356     1.0    Kremenchuk              Ukraine
# 2                  6           21     3.0        Madrid                Spain
# 3                  5            6     5.0        Zagreb              Croatia
# 4                  5          160     2.0        Dundee       United Kingdom
# ...              ...          ...     ...           ...                  ...
# 4024140            5           99     1.0  Vatican City              Vatican
# 4024141            3          125     1.0  Vatican City              Vatican
# 4024142            4          280     1.0  Vatican City              Vatican
# 4024143            0          346     1.0  Vatican City              Vatican
# 4024144            0          346     1.0  Vatican City              Vatican
#
#         distance_km
# 0             21.48
# 1             24.04
# 2             15.05
# 3             70.12
# 4             43.53
# ...             ...
# 4024140        0.36
# 4024141        0.36
# 4024142        0.36
# 4024143        0.36
# 4024144        0.36
#
# [4024145 rows x 29 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# histogram
axes[0].hist(df_native['distance_km'].dropna(), bins=100, color='steelblue', edgecolor='white')
axes[0].set_title('Distribution of Distance to Closest City')
axes[0].set_xlabel('Distance (km)')
axes[0].set_ylabel('Count')

# log scale histogram (useful if data is right-skewed)
axes[1].hist(df_native['distance_km'].dropna(), bins=100, color='steelblue', edgecolor='white')
axes[1].set_yscale('log')
axes[1].set_title('Distribution (Log')
axes[1].set_xlabel('Distance (km)')
axes[1].set_ylabel('Count (log)')


plt.tight_layout()
plt.savefig("distance_distribution.png", dpi=150)
plt.show()

# %%
print(df_native['distance_km'].describe())
print(f"\nMedian:  {df_native['distance_km'].median():.2f} km")
print(f"Skewness: {df_native['distance_km'].skew():.2f}")
print(f"% within 10km:  {(df_native['distance_km'] <= 10).mean()*100:.1f}%")
print(f"% within 50km:  {(df_native['distance_km'] <= 50).mean()*100:.1f}%")
print(f"% within 100km: {(df_native['distance_km'] <= 100).mean()*100:.1f}%")
# Out:
# count    4.024145e+06
# mean     4.176515e+01
# std      1.133242e+02
# min      2.000000e-02
# 25%      1.320000e+01
# 50%      2.829000e+01
# 75%      4.897000e+01
# max      2.188640e+03
# Name: distance_km, dtype: float64
#
# Median:  28.29 km
# Skewness: 15.16
# % within 10km:  18.2%
# % within 50km:  75.9%
# % within 100km: 95.9%

# %%
# check what's driving the outliers
outliers = df_native[df_native['distance_km'] > 500]
print(outliers['COUNTRY CODE'].value_counts())
print(outliers[['LATITUDE', 'LONGITUDE', 'COUNTRY CODE', 'distance_km']].head(20))
# Out:
# COUNTRY CODE
# PT    11392
# ES     5084
# Name: count, dtype: int64
#        LATITUDE  LONGITUDE COUNTRY CODE  distance_km
# 68    27.988852 -15.593290           ES      1182.65
# 130   28.160268 -16.642399           ES      1270.53
# 394   28.190192 -16.665776           ES      1271.06
# 716   28.190192 -16.665776           ES      1271.06
# 867   27.961783 -15.619554           ES      1186.77
# 870   28.190192 -16.665776           ES      1271.06
# 1236  28.165900 -16.638700           ES      1269.85
# 1563  28.006094 -15.599630           ES      1182.15
# 1581  28.190192 -16.665776           ES      1271.06
# 1584  28.026758 -15.612892           ES      1182.07
# 1700  28.257575 -16.769551           ES      1277.21
# 1933  28.190192 -16.665776           ES      1271.06
# 2217  28.155805 -16.637995           ES      1270.36
# 2605  27.951713 -15.651890           ES      1190.36
# 2883  28.165900 -16.638700           ES      1269.85
# 3497  28.190192 -16.665776           ES      1271.06
# 3653  27.965669 -15.595093           ES      1184.28
# 4442  28.447015 -16.411675           ES      1232.22
# 5120  27.956773 -15.595361           ES      1184.87
# 5173  27.929361 -15.665888           ES      1193.06

# %% [markdown]
# ## Migratory

# %%
import pandas as pd
import numpy as np
from scipy.spatial import cKDTree

# build KD-Tree on city coordinates ---
# convert lat/lon to radians for accurate distance calculation
cities_rad = np.radians(cities[['lat', 'lon']].values)
tree = cKDTree(cities_rad)

# find closest city for each bird observation ---
birds_rad = np.radians(df_migratory[['LATITUDE', 'LONGITUDE']].values)
distances, indices = tree.query(birds_rad, k=1)

# convert distance from radians to kilometers (Earth radius = 6371 km)
df_migratory['closest_city'] = cities['NAME'].iloc[indices].values
df_migratory['closest_city_country'] = cities['ADM0NAME'].iloc[indices].values
df_migratory['distance_km'] = np.round(distances * 6371, 2)

df_migratory
# Out:
#               COMMON NAME    SCIENTIFIC NAME  OBSERVATION COUNT AGE/SEX  \
# 0       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 1       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 2       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 3       Eurasian Whimbrel  Numenius phaeopus                2.0     NaN
# 4       Eurasian Whimbrel  Numenius phaeopus                3.0     NaN
# ...                   ...                ...                ...     ...
# 863367         Black Tern   Chlidonias niger                1.0     NaN
# 863368         Black Tern   Chlidonias niger                1.0     NaN
# 863369         Black Tern   Chlidonias niger                1.0     NaN
# 863370         Black Tern   Chlidonias niger                1.0     NaN
# 863371         Black Tern   Chlidonias niger                2.0     NaN
#
#                COUNTRY COUNTRY CODE               STATE STATE CODE  \
# 0                Spain           ES          AndalucÃ­a      ES-AN
# 1                Spain           ES          AndalucÃ­a      ES-AN
# 2                Spain           ES          AndalucÃ­a      ES-AN
# 3                Spain           ES          AndalucÃ­a      ES-AN
# 4                Spain           ES            Canarias      ES-CN
# ...                ...          ...                 ...        ...
# 863367     Netherlands           NL        Zuid-Holland      NL-ZH
# 863368          Poland           PL  Kujawsko-pomorskie      PL-KP
# 863369  United Kingdom           GB             England     GB-ENG
# 863370         Ireland           IE           Connaught       IE-C
# 863371         Ireland           IE            Leinster       IE-L
#
#                COUNTY COUNTY CODE  ...  OBSERVATION TYPE       obsDt  year  \
# 0              CÃ¡diz    ES-AN-CD  ...         Traveling  2017-01-20  2017
# 1              Huelva    ES-AN-HL  ...         Traveling  2017-01-16  2017
# 2              Huelva    ES-AN-HL  ...         Traveling  2017-01-16  2017
# 3              Huelva    ES-AN-HL  ...         Traveling  2017-01-16  2017
# 4       Fuerteventura   ES-CN-FVT  ...         Traveling  2017-01-21  2017
# ...               ...         ...  ...               ...         ...   ...
# 863367            NaN         NaN  ...        Stationary  2025-09-16  2025
# 863368            NaN         NaN  ...        Stationary  2025-09-19  2025
# 863369     Merseyside  GB-ENG-KWL  ...         Traveling  2025-10-05  2025
# 863370           Mayo     IE-C-MO  ...         Traveling  2025-10-09  2025
# 863371         Dublin     IE-L-DN  ...        Stationary  2025-10-02  2025
#
#        month  day_of_week  day_of_year howMany closest_city  \
# 0          1            4           20     2.0    Algeciras
# 1          1            0           16     2.0       Huelva
# 2          1            0           16     2.0       Huelva
# 3          1            0           16     2.0       Huelva
# 4          1            5           21     3.0        Rabat
# ...      ...          ...          ...     ...          ...
# 863367     9            1          259     1.0    The Hague
# 863368     9            4          262     1.0   Inowrocław
# 863369    10            6          278     1.0    Liverpool
# 863370    10            3          282     1.0       Galway
# 863371    10            3          275     2.0       Dublin
#
#        closest_city_country distance_km
# 0                     Spain       22.80
# 1                     Spain        6.90
# 2                     Spain        6.90
# 3                     Spain        6.90
# 4                   Morocco     1003.72
# ...                     ...         ...
# 863367          Netherlands        4.36
# 863368               Poland       21.10
# 863369       United Kingdom        9.70
# 863370              Ireland      153.90
# 863371              Ireland       20.17
#
# [863372 rows x 29 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# histogram
axes[0].hist(df_migratory['distance_km'].dropna(), bins=100, color='steelblue', edgecolor='white')
axes[0].set_title('Distribution of Distance to Closest City')
axes[0].set_xlabel('Distance (km)')
axes[0].set_ylabel('Count')

# log scale histogram (useful if data is right-skewed)
axes[1].hist(df_migratory['distance_km'].dropna(), bins=100, color='steelblue', edgecolor='white')
axes[1].set_yscale('log')
axes[1].set_title('Distribution (Log')
axes[1].set_xlabel('Distance (km)')
axes[1].set_ylabel('Count (log)')


plt.tight_layout()
plt.savefig("distance_distribution.png", dpi=150)
plt.show()

# %%
print(df_migratory['distance_km'].describe())
print(f"\nMedian:  {df_migratory['distance_km'].median():.2f} km")
print(f"Skewness: {df_migratory['distance_km'].skew():.2f}")
print(f"% within 10km:  {(df_migratory['distance_km'] <= 10).mean()*100:.1f}%")
print(f"% within 50km:  {(df_migratory['distance_km'] <= 50).mean()*100:.1f}%")
print(f"% within 100km: {(df_migratory['distance_km'] <= 100).mean()*100:.1f}%")
# Out:
# count    863372.000000
# mean         75.120181
# std         242.817631
# min           0.060000
# 25%          20.760000
# 50%          35.700000
# 75%          58.920000
# max        2460.870000
# Name: distance_km, dtype: float64
#
# Median:  35.70 km
# Skewness: 7.41
# % within 10km:  8.5%
# % within 50km:  66.7%
# % within 100km: 92.9%

# %%
# check what's driving the outliers
outliers = df_migratory[df_migratory['distance_km'] > 500]
print(outliers['COUNTRY CODE'].value_counts())
print(outliers[['LATITUDE', 'LONGITUDE', 'COUNTRY CODE', 'distance_km']].head(20))
# Out:
# COUNTRY CODE
# PT    11871
# ES     4365
# Name: count, dtype: int64
#      LATITUDE  LONGITUDE COUNTRY CODE  distance_km
# 4   28.367192 -13.869656           ES      1003.72
# 5   28.367192 -13.869656           ES      1003.72
# 16  38.524264 -28.628097           PT      2166.33
# 17  38.393810 -28.254347           PT      2124.98
# 18  38.393810 -28.254347           PT      2124.98
# 19  38.393810 -28.254347           PT      2124.98
# 20  38.393810 -28.254347           PT      2124.98
# 21  38.393810 -28.254347           PT      2124.98
# 22  38.393810 -28.254347           PT      2124.98
# 23  38.535062 -28.530885           PT      2155.51
# 24  38.706343 -27.047567           PT      1990.47
# 25  38.706343 -27.047567           PT      1990.47
# 26  32.742671 -16.701794           PT      1031.21
# 27  32.742671 -16.701794           PT      1031.21
# 32  28.375467 -16.864716           ES      1279.89
# 36  38.522603 -28.668768           PT      2170.86
# 37  38.522603 -28.668768           PT      2170.86
# 38  38.706343 -27.047567           PT      1990.47
# 39  38.706343 -27.047567           PT      1990.47
# 40  38.706343 -27.047567           PT      1990.47
