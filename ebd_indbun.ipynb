# %%
import pandas as pd
import os

# %%
print(os.getcwd())
os.chdir("/mnt/c/Users/user/Desktop/Uni/Year 2/Winter/Dasta science project/MAIN project ideas")
print(os.getcwd())
# Out:
# /home/shiwam/ceu-ds-project-groupB-2026
# /mnt/c/Users/user/Desktop/Uni/Year 2/Winter/Dasta science project/MAIN project ideas

# %%
# Specify path to the data set file (your file might have a different name and path from mine!)
path_to_folder = 'data'
file_path = os.path.join(path_to_folder, 'ebd_indbun_201801_202612_smp_relDec-2025.txt')
# We use sep='\t' because eBird files are Tab-Separated
# We use nrows=5 to just grab a tiny sample
try:
    df = pd.read_csv(file_path, sep='\t', nrows=5)

    # This makes the output "beautiful" in the console
    pd.set_option('display.max_columns', None)  # Show all columns
    pd.set_option('display.width', 1000)        # Don't wrap lines
    
    print("---eBird Data Preview---")
    print(df.head(20))
    
    print("\n--- Column Names (So you know what you can filter by) ---")
    print(df.columns.tolist())

except FileNotFoundError:
    print("Error: The file wasn't found. Double-check the file path!")
# Out:
# ---eBird Data Preview---
#                           GLOBAL UNIQUE IDENTIFIER            LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID     COMMON NAME   SCIENTIFIC NAME  SUBSPECIES COMMON NAME  SUBSPECIES SCIENTIFIC NAME  EXOTIC CODE  OBSERVATION COUNT  BREEDING CODE  BREEDING CATEGORY  BEHAVIOR CODE  AGE/SEX              COUNTRY COUNTRY CODE       STATE STATE CODE  COUNTY  COUNTY CODE              IBA CODE  BCR CODE  USFWS CODE  ATLAS BLOCK                  LOCALITY LOCALITY ID LOCALITY TYPE   LATITUDE  LONGITUDE OBSERVATION DATE TIME OBSERVATIONS STARTED  OBSERVER ID  OBSERVER ORCID ID SAMPLING EVENT IDENTIFIER OBSERVATION TYPE PROTOCOL NAME PROTOCOL CODE  PROJECT NAMES  PROJECT IDENTIFIERS  DURATION MINUTES  EFFORT DISTANCE KM  EFFORT AREA HA  NUMBER OBSERVERS  ALL SPECIES REPORTED GROUP IDENTIFIER  HAS MEDIA  APPROVED  REVIEWED  REASON  CHECKLIST COMMENTS                  SPECIES COMMENTS  Unnamed: 52
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS2576451036  2025-10-28 12:04:47.504505            34607  species  avibase-043F337A  Indigo Bunting  Passerina cyanea                     NaN                         NaN          NaN                  1            NaN                NaN            NaN      NaN  Antigua and Barbuda           AG  Saint Paul      AG-06     NaN          NaN  BIRDLIFE_20749|AG010       NaN         NaN          NaN              Potworks Dam    L2751901             H  17.063677 -61.755352       2024-10-31                  06:02:00  obsr3832483                NaN                S200888392        Traveling     Traveling           P22            NaN                  NaN               158               4.551             NaN                 2                     1        G13295629          1         1         1     NaN                 NaN         Immature - photo attached          NaN
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS2576450726  2025-10-28 12:04:47.291295            34607  species  avibase-043F337A  Indigo Bunting  Passerina cyanea                     NaN                         NaN          NaN                  1            NaN                NaN            NaN      NaN  Antigua and Barbuda           AG  Saint Paul      AG-06     NaN          NaN  BIRDLIFE_20749|AG010       NaN         NaN          NaN              Potworks Dam    L2751901             H  17.063677 -61.755352       2024-10-31                  06:02:00   obsr640951                NaN                S200881079        Traveling     Traveling           P22            NaN                  NaN               158               4.551             NaN                 2                     1        G13295629          1         1         1     NaN                 NaN         Immature. Photo attached.          NaN
# 2   URN:CornellLabOfOrnithology:EBIRD:OBS594145102  2021-04-02 03:20:42.553548            34607  species  avibase-043F337A  Indigo Bunting  Passerina cyanea                     NaN                         NaN          NaN                  1            NaN                NaN            NaN      NaN                Aruba           AW       Aruba        AW-     NaN          NaN                   NaN       NaN         NaN          NaN   Balashi Gold Mill Ruins    L1959304             P  12.483667 -69.973104       2018-03-31                  08:00:00   obsr378378                NaN                 S44140246        Traveling     Traveling           P22            NaN                  NaN               120               2.000             NaN                 3                     1              NaN          1         1         1     NaN                 NaN                               NaN          NaN
# 3   URN:CornellLabOfOrnithology:EBIRD:OBS598005488   2025-07-31 13:01:30.24159            34607  species  avibase-043F337A  Indigo Bunting  Passerina cyanea                     NaN                         NaN          NaN                  1            NaN                NaN            NaN      NaN                Aruba           AW       Aruba        AW-     NaN          NaN                   NaN       NaN         NaN          NaN     Near Elmar Oranjestad    L7192778             P  12.533560 -70.006453       2018-04-10                  10:20:00   obsr660137                NaN                 S44429292        Traveling     Traveling           P22            NaN                  NaN                53               0.750             NaN                 1                     1              NaN          0         1         1     NaN                 NaN  Male, blue, too fast no picture.          NaN
# 4   URN:CornellLabOfOrnithology:EBIRD:OBS599266674  2025-10-12 16:14:13.472105            34607  species  avibase-043F337A  Indigo Bunting  Passerina cyanea                     NaN                         NaN          NaN                  3            NaN                NaN            NaN      NaN                Aruba           AW       Aruba        AW-     NaN          NaN                   NaN       NaN         NaN          NaN  Divi Village Golf Course    L2119588             H  12.538142 -70.056124       2018-04-12                  09:00:00   obsr378378                NaN                 S44522616        Traveling     Traveling           P22            NaN                  NaN                35               1.000             NaN                 2                     1              NaN          1         1         1     NaN                 NaN                               NaN          NaN
#
# --- Column Names (So you know what you can filter by) ---
# ['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER', 'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME', 'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE', 'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY', 'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE', 'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE', 'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE', 'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE', 'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'OBSERVER ORCID ID', 'SAMPLING EVENT IDENTIFIER', 'OBSERVATION TYPE', 'PROTOCOL NAME', 'PROTOCOL CODE', 'PROJECT NAMES', 'PROJECT IDENTIFIERS', 'DURATION MINUTES', 'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS', 'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED', 'REVIEWED', 'REASON', 'CHECKLIST COMMENTS', 'SPECIES COMMENTS', 'Unnamed: 52']

# %%
df.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER', 'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME', 'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE', 'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY', 'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE', 'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE', 'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE', 'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE', 'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'OBSERVER ORCID ID', 'SAMPLING EVENT IDENTIFIER', 'OBSERVATION TYPE', 'PROTOCOL NAME', 'PROTOCOL CODE', 'PROJECT NAMES', 'PROJECT IDENTIFIERS', 'DURATION MINUTES', 'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS', 'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED', 'REVIEWED', 'REASON', 'CHECKLIST COMMENTS', 'SPECIES COMMENTS', 'Unnamed: 52'], dtype='str')
